# %% [markdown]
# How many different states and territories?

# %%
import sqlite3
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
df = pd.read_excel(r'C:/Users/AokoK/Downloads/DMS Technical Data.xlsx')
df
# Out:
#       State FIPS    State  116th Congressional District  \
# 0              1  Alabama                             7
# 1              1  Alabama                             7
# 2              1  Alabama                             2
# 3              1  Alabama                             1
# 4              1  Alabama                             1
# ...          ...      ...                           ...
# 8651          56  Wyoming                             0
# 8652          56  Wyoming                             0
# 8653          56  Wyoming                             0
# 8654          56  Wyoming                             0
# 8655          56  Wyoming                             0
#
#                                   NAICS Description  Number of Establishments  \
# 0     Other services (except public administration)                      1538
# 1              Administrative and support and waste                       538
# ...

# %%
df.nunique()
# Out:
# State FIPS                        52
# State                             52
# 116th Congressional District      54
# NAICS Description                 20
# Number of Establishments        2616
# Employment                      7072
# 1st Quarter Payroll ($1,000)    8335
# Annual Payroll                  8566
# Unnamed: 8                         0
# Unnamed: 9                        15
# Unnamed: 10                        0
# Unnamed: 11                        1
# Unnamed: 12                        0
# Unnamed: 13                        4
# Unnamed: 14                        1
# Unnamed: 15                        1
# dtype: int64

# %% [markdown]
# We have 52 states and territories as the second line informs us.

# %% [markdown]
# How many people are employed in Michigan?

# %%
ndf = df[df['State'] == 'Michigan']
ndf['Employment'].sum()
# Out:
# 3803597

# %% [markdown]
# What is the state that spends the most on healthcare and social assistance?

# %%
hdf = df[df['NAICS Description'] == 'Health care and social assistance']
sdf = hdf.groupby('State').sum()
sdf
# Out:
#                       State FIPS  116th Congressional District  \
# State
# Alabama                        7                            28
# Alaska                         2                             0
# Arizona                       36                            45
# Arkansas                      20                            10
# California                   318                          1431
# Colorado                      56                            28
# Connecticut                   45                            15
# Delaware                      10                             0
# District of Columbia          11                             0
# Florida                      324                           378
# Georgia                      182                           105
# Hawaii                        30                             3
# Idaho                         32                             3
# Illinois                     306                           171
# ...

# %%
state = hdf[hdf['Annual Payroll'] == hdf['Annual Payroll'].max()]
state
# Out:
#       State FIPS     State  116th Congressional District  \
# 5450          36  New York                            12
#
#                       NAICS Description  Number of Establishments  Employment  \
# 5450  Health care and social assistance                      5534      172404
#
#       1st Quarter Payroll ($1,000)  Annual Payroll  Unnamed: 8 Unnamed: 9  \
# 5450                       3242715        13399260         NaN        NaN
#
#       Unnamed: 10 Unnamed: 11  Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15
# 5450          NaN         NaN          NaN         NaN         NaN         NaN

# %% [markdown]
# What is the average number of people employed in information per state?

# %%
idf = df[df['NAICS Description'] == 'Information']
idf
# Out:
#       State FIPS      State  116th Congressional District NAICS Description  \
# 3              1    Alabama                             1       Information
# 34             1    Alabama                             5       Information
# 56             1    Alabama                             7       Information
# 69             1    Alabama                             4       Information
# 70             1    Alabama                             6       Information
# ...          ...        ...                           ...               ...
# 8557          55  Wisconsin                             7       Information
# 8606          55  Wisconsin                             1       Information
# 8627          55  Wisconsin                             4       Information
# 8629          55  Wisconsin                             3       Information
# 8637          56    Wyoming                             0       Information
#
# ...

# %%
iidf=idf.groupby('State').sum()
iidf
# Out:
#                       State FIPS  116th Congressional District  \
# State
# Alabama                        7                            28
# Alaska                         2                             0
# Arizona                       36                            45
# Arkansas                      20                            10
# California                   318                          1431
# Colorado                      56                            28
# Connecticut                   45                            15
# Delaware                      10                             0
# District of Columbia          11                             0
# Florida                      324                           378
# Georgia                      182                           105
# Hawaii                        30                             3
# Idaho                         32                             3
# Illinois                     306                           171
# ...

# %%
average = iidf['Employment'].mean()
average
# Out:
# 67843.19230769231

# %% [markdown]
# How to create a chart with grand totals of annual payroll per state?

# %%
qdf=df.groupby('State').sum()
qqdf=qdf['Annual Payroll']
qqdf
# Out:
# State
# Alabama                   78511870
# Alaska                    16331033
# Arizona                  127707100
# Arkansas                  46511722
# California              1064055216
# Colorado                 135055306
# Connecticut               97946152
# Delaware                  25114966
# District of Columbia      45849643
# Florida                  356446492
# Georgia                  206393176
# Hawaii                    22282535
# Idaho                     28161365
# Illinois                 319396518
# Indiana                  128113333
# Iowa                      63395133
# Kansas                    56687166
# Kentucky                  73812606
# Louisiana                 76978635
# Maine                     24306778
# Maryland                 135115101
# Massachusetts            237463926
# Michigan                 195742400
# Minnesota                148983144
# Mississippi               37247579
# Missouri                 124078748
# ...

# %% [markdown]
# How to calculate quartiles?

# %%
qdf.describe()
# Out:
# count    5.200000e+01
# mean     1.385371e+08
# std      1.817401e+08
# min      1.010742e+07
# 25%      2.806176e+07
# 50%      7.747293e+07
# 75%      1.936616e+08
# max      1.064055e+09
# Name: Annual Payroll, dtype: float64

# %% [markdown]
# Here we see 5th-7th entries giving the quartiles.
